# %% [markdown]
# ## Function

# %%
import turtle

def draw_square(t, sz):
    """Make turtle t draw a square of sz."""
    for i in range(4):
        t.forward(sz)
        t.left(90)

wn = turtle.Screen()
wn.bgcolor("lightgreen")
wn.title("Alex meets a function")

alex = turtle.Turtle()
draw_square(alex,50)

wn.mainloop()

# %%
import turtle

def draw_multicolor_square(t, sz):
    """Make turtle t draw a multi-color square of sz."""
    for i in ["red", "purple", "hotpink", "blue"]:
        t.color(i)
        t.forward(sz)
        t.left(90)

wn = turtle.Screen()
wn.bgcolor("lightgreen")

tess = turtle.Turtle()
tess.pensize(3)

size = 20

for i in range(15):
    draw_multicolor_square(tess, size)
    size = size + 10
    tess.forward(10)
    tess.right(18)

wn.mainloop()

# %%
def final_amt(p, r, n, t):
    """
    Apply the compound interest formula to p
    to produce the final amount.
    """
    a = p * (1 + r/n) ** (n * t)
    return a # This is new, and makes the function fruitful.

toInvest = float(input("How much do you want to invest?"))
fnl = final_amt(toInvest, 0.08, 12, 5)
print("At the end of the period you'll have", fnl)
# Out:
# At the end of the period you'll have 744.9228541508026

# %%
import turtle

def make_window(colr, ttle):
    w = turtle.Screen()
    w.bgcolor(colr)
    w.title(ttle)
    return w

def make_turtle(colr, sz):
    t = turtle.Turtle()
    t.color(colr)
    t.pensize(sz)
    return t

wn = make_window("lightgreen", "Tess and Alex dancing")
tess = make_turtle("hotpink", 5)
alex = make_turtle("black", 1)
dave = make_turtle("yellow", 2)

tess.forward(50)
alex.back(100)
dave.right(90)
dave.forward(120)

wn.mainloop()

# %% [markdown]
# ## exersice

# %%
import turtle

def draw_square(turtleName, squareSize):
    for i in range(4):
        turtleName.forward(squareSize)
        turtleName.left(90)

wn = turtle.Screen()
wn.bgcolor("lightgreen")

alex = turtle.Turtle()
alex.pensize(3)
alex.color("hotpink")

for i in range(5):
    draw_square(alex, 20)
    alex.penup()
    alex.forward(40)
    alex.pendown()

wn.mainloop()

# %%
import turtle

def draw_square(turtleName, squareSize):
    for i in range(4):
        turtleName.forward(squareSize)
        turtleName.left(90)

wn = turtle.Screen()
wn.bgcolor("lightgreen")

alex = turtle.Turtle()
alex.pensize(3)
alex.color("hotpink")
sz = 20

for i in range(5):
    draw_square(alex, sz)
    alex.penup()
    alex.right(90)
    alex.forward(20)
    alex.left(90)
    alex.back(20)
    alex.pendown()
    sz = sz + 40

wn.mainloop()

# %%
import turtle

def draw_poly(turtleName, n, polySize):
    for i in range(n):
        turtleName.forward(polySize)
        turtleName.left(45)

wn = turtle.Screen()
wn.bgcolor("lightgreen")

alex = turtle.Turtle()
alex.pensize(3)
alex.color("hotpink")

draw_poly(alex, 8, 50)

wn.mainloop()

# %%
import turtle

def draw_square(turtleName, squareSize):
    for i in range(4):
        turtleName.forward(squareSize)
        turtleName.left(90)
    
wn = turtle.Screen()
wn.bgcolor("lightgreen")

tess = turtle.Turtle()
tess.color("blue")

for i in range(20):
    draw_square(tess, 90)
    tess.left(18)

wn.mainloop()

# %%
import turtle

def draw_spiral(turtleName, stepNumber, firstLenth, stepLenth, turnAngel):
    for i in range(stepNumber):
        turtleName.right(turnAngel)
        turtleName.forward(firstLenth)
        firstLenth = firstLenth + stepLenth

wn = turtle.Screen()
wn.bgcolor("lightgreen")

tess = turtle.Turtle()
tess.color("blue")

draw_spiral(tess, 200, 1, 2, 91)

wn.mainloop()

# %%
def sum_to(n):
    sum = 0
    for i in range(n):
        sum = sum + i
    sum = sum + i + 1
    return sum

print(sum_to(100))
# Out:
# 5050

# %%
import turtle

def draw_star(turtleName, sideLenth):
    for i in range(5):
        turtleName.forward(sideLenth)
        turtleName.right(144)

wn = turtle.Screen()
wn.bgcolor("lightgreen")

tess = turtle.Turtle()
tess.color("hotpink")

for i in range(5):
    draw_star(tess, 100)
    tess.penup()
    tess.forward(350)
    tess.right(144)
    tess.pendown()

wn.mainloop()
